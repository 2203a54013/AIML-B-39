# %%
import pandas as pd
df=pd.read_csv("train.csv",na_values=["not available","n.a."])
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2  ...         20       756  2549     9     7
# 1       0.7        136        3  ...        905      1988  2631    17     3
# 2       0.9        145        5  ...       1263      1716  2603    11     2
# 3       0.8        131        6  ...       1216      1786  2769    16     8
# 4       0.6        141        2  ...       1208      1212  1411     8     2
# ...     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# 0            19        0             0     1            1
# 1             7        1             1     0            2
# 2             9        1             1     0            2
# 3            11        1             0     0            2
# 4            15        1             1     0            1
# ...         ...      ...           ...   ...          ...
# 1995         19        1             1     0            0
# 1996         16        1             1     1            2
# 1997          5        1             1     0            3
# 1998         19        1             1     1            0
# 1999          2        1             1     1            3
#
# [2000 rows x 21 columns]

# %%
df.dtypes
# Out:
# battery_power      int64
# blue               int64
# clock_speed      float64
# dual_sim           int64
# fc                 int64
# four_g             int64
# int_memory         int64
# m_dep            float64
# mobile_wt          int64
# n_cores            int64
# pc                 int64
# px_height          int64
# px_width           int64
# ram                int64
# sc_h               int64
# sc_w               int64
# talk_time          int64
# three_g            int64
# touch_screen       int64
# wifi               int64
# price_range        int64
# dtype: object

# %%
X=df.iloc[:, 0 :19]
y=df.iloc[:,20]

# %%
X
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0       0.6        188        2   2         20       756  2549     9     7
# 1       0.7        136        3   6        905      1988  2631    17     3
# 2       0.9        145        5   6       1263      1716  2603    11     2
# 3       0.8        131        6   9       1216      1786  2769    16     8
# 4       0.6        141        2  14       1208      1212  1411     8     2
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1995    0.8        106        6  14       1222      1890   668    13     4
# 1996    0.2        187        4   3        915      1965  2032    11    10
# 1997    0.7        108        8   3        868      1632  3057     9     1
# 1998    0.1        145        5   5        336       670   869    18    10
# 1999    0.9        168        6  16        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen
# 0            19        0             0
# 1             7        1             1
# 2             9        1             1
# 3            11        1             0
# 4            15        1             1
# ...         ...      ...           ...
# 1995         19        1             1
# 1996         16        1             1
# 1997          5        1             1
# 1998         19        1             1
# 1999          2        1             1
#
# [2000 rows x 19 columns]

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test =train_test_split(X,y,random_state=34)

# %%
X_train
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1780            909     1          0.7         1   7       0          47
# 1497           1375     0          2.9         0   2       0          20
# 1577            999     0          1.7         0   6       0          49
# 1417           1987     1          1.9         0   0       0          50
# 1040           1154     0          0.5         0  12       1          14
# ...             ...   ...          ...       ...  ..     ...         ...
# 1782           1436     1          2.4         1   3       1          23
# 1897           1075     0          0.5         1   2       0          11
# 490             685     0          2.7         0   7       0          17
# 1146           1923     0          1.0         1   5       1          14
# 1441            599     1          2.9         0   0       1          64
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1780    0.1        146        3   9        410      1643  1244    14    10
# 1497    0.4        147        6   7        596       679  3847     8     0
# 1577    0.6        132        1  17        608      1970  1598     7     0
# 1417    0.7        119        8  18        960      1925   857    12     4
# 1040    0.7        156        7  14        251      1801   587     8     3
# ...     ...        ...      ...  ..        ...       ...   ...   ...   ...
# 1782    0.3        106        5   4        189      1411  2488     8     4
# 1897    0.2        122        1  16        271      1769  3927     8     3
# 490     0.3        174        6  20        725       870  1223     8     0
# 1146    0.9        154        4   6         15       525  2519    13     0
# 1441    0.3        186        8   1        103       646  3396     5     3
#
#       talk_time  three_g  touch_screen
# 1780         16        0             1
# 1497         12        1             0
# 1577          8        0             1
# 1417          6        1             1
# 1040          4        1             1
# ...         ...      ...           ...
# 1782          8        1             0
# 1897          7        1             0
# 490          18        1             0
# 1146         16        1             0
# 1441          7        1             0
#
# [1500 rows x 19 columns]

# %%
scaler=MinMaxScaler().fit(X_train)

# %%
print(scaler)
# Out:
# MinMaxScaler()

# %%
scaler.data_max_
# Out:
# array([1.997e+03, 1.000e+00, 3.000e+00, 1.000e+00, 1.900e+01, 1.000e+00,
#        6.400e+01, 1.000e+00, 2.000e+02, 8.000e+00, 2.000e+01, 1.960e+03,
#        1.998e+03, 3.998e+03, 1.900e+01, 1.800e+01, 2.000e+01, 1.000e+00,
#        1.000e+00])

# %%
X_train.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean     1238.931333     0.492000     1.532467     0.510000     4.258000
# std       445.225086     0.500103     0.817328     0.500067     4.319245
# min       501.000000     0.000000     0.500000     0.000000     0.000000
# 25%       842.750000     0.000000     0.700000     0.000000     1.000000
# 50%      1233.000000     0.000000     1.500000     1.000000     3.000000
# 75%      1624.000000     1.000000     2.300000     1.000000     7.000000
# max      1997.000000     1.000000     3.000000     1.000000    19.000000
#
#            four_g   int_memory        m_dep    mobile_wt     n_cores  \
# count  1500.00000  1500.000000  1500.000000  1500.000000  1500.00000
# mean      0.52600    32.241333     0.504933   140.358000     4.52600
# std       0.49949    18.217876     0.291237    35.465669     2.29946
# min       0.00000     2.000000     0.100000    80.000000     1.00000
# 25%       0.00000    16.000000     0.200000   109.000000     3.00000
# 50%       1.00000    32.000000     0.500000   141.000000     4.50000
# 75%       1.00000    48.000000     0.800000   171.000000     7.00000
# max       1.00000    64.000000     1.000000   200.000000     8.00000
#
#                 pc    px_height     px_width          ram         sc_h  \
# count  1500.000000  1500.000000  1500.000000  1500.000000  1500.000000
# mean      9.996000   644.670667  1242.060000  2139.786000    12.262667
# std       5.975488   441.865644   429.601241  1086.584823     4.218555
# min       0.000000     0.000000   500.000000   256.000000     5.000000
# 25%       5.000000   283.750000   872.750000  1212.750000     9.000000
# 50%      10.000000   563.500000  1234.500000  2182.500000    12.000000
# 75%      15.000000   944.250000  1616.250000  3079.250000    16.000000
# max      20.000000  1960.000000  1998.000000  3998.000000    19.000000
#
#               sc_w    talk_time      three_g  touch_screen
# count  1500.000000  1500.000000  1500.000000   1500.000000
# mean      5.732667    11.038000     0.766667      0.500000
# std       4.341632     5.434849     0.423094      0.500167
# min       0.000000     2.000000     0.000000      0.000000
# 25%       2.000000     6.000000     1.000000      0.000000
# 50%       5.000000    11.000000     1.000000      0.500000
# 75%       9.000000    16.000000     1.000000      1.000000
# max      18.000000    20.000000     1.000000      1.000000

# %%
scaler.feature_range
# Out:
# (0, 1)

# %%
scaler.transform(X_train)
# Out:
# array([[0.27272727, 1.        , 0.08      , ..., 0.77777778, 0.        ,
#         1.        ],
#        [0.5842246 , 0.        , 0.96      , ..., 0.55555556, 1.        ,
#         0.        ],
#        [0.3328877 , 0.        , 0.48      , ..., 0.33333333, 0.        ,
#         1.        ],
#        ...,
#        [0.12299465, 0.        , 0.88      , ..., 0.88888889, 1.        ,
#         0.        ],
#        [0.95053476, 0.        , 0.2       , ..., 0.77777778, 1.        ,
#         0.        ],
#        [0.06550802, 1.        , 0.96      , ..., 0.27777778, 1.        ,
#         0.        ]])

# %%
X_train_scaled=scaler.transform(X_train)

# %%
print(X_train_scaled)
# Out:
# [[0.27272727 1.         0.08       ... 0.77777778 0.         1.        ]
#  [0.5842246  0.         0.96       ... 0.55555556 1.         0.        ]
#  [0.3328877  0.         0.48       ... 0.33333333 0.         1.        ]
#  ...
#  [0.12299465 0.         0.88       ... 0.88888889 1.         0.        ]
#  [0.95053476 0.         0.2        ... 0.77777778 1.         0.        ]
#  [0.06550802 1.         0.96       ... 0.27777778 1.         0.        ]]

# %%
scaler=MinMaxScaler().fit(X_test)

# %%
print(scaler)
# Out:
# MinMaxScaler()

# %%
scaler.data_max_
# Out:
# array([1.998e+03, 1.000e+00, 3.000e+00, 1.000e+00, 1.800e+01, 1.000e+00,
#        6.400e+01, 1.000e+00, 2.000e+02, 8.000e+00, 2.000e+01, 1.914e+03,
#        1.997e+03, 3.991e+03, 1.900e+01, 1.800e+01, 2.000e+01, 1.000e+00,
#        1.000e+00])

# %%
X_test.describe()
# Out:
#        battery_power        blue  clock_speed    dual_sim          fc  \
# count     500.000000  500.000000   500.000000  500.000000  500.000000
# mean     1237.280000    0.504000     1.491600    0.508000    4.464000
# std       421.949785    0.500485     0.812064    0.500437    4.408125
# min       502.000000    0.000000     0.500000    0.000000    0.000000
# 25%       877.250000    0.000000     0.700000    0.000000    1.000000
# 50%      1211.500000    1.000000     1.400000    1.000000    3.000000
# 75%      1584.500000    1.000000     2.200000    1.000000    7.000000
# max      1998.000000    1.000000     3.000000    1.000000   18.000000
#
#            four_g  int_memory      m_dep   mobile_wt     n_cores          pc  \
# count  500.000000  500.000000  500.00000  500.000000  500.000000  500.000000
# mean     0.508000   31.462000    0.49220  139.922000    4.504000    9.678000
# std      0.500437   17.932867    0.27985   35.234228    2.254806    6.323471
# min      0.000000    2.000000    0.10000   80.000000    1.000000    0.000000
# 25%      0.000000   16.000000    0.20000  109.000000    3.000000    4.000000
# 50%      1.000000   30.000000    0.50000  139.000000    4.000000    9.000000
# 75%      1.000000   47.000000    0.70000  170.000000    6.000000   15.000000
# max      1.000000   64.000000    1.00000  200.000000    8.000000   20.000000
#
#          px_height     px_width          ram       sc_h        sc_w  \
# count   500.000000   500.000000   500.000000  500.00000  500.000000
# mean    646.420000  1279.882000  2077.494000   12.43800    5.870000
# std     449.921173   439.115083  1078.888557    4.19874    4.403167
# min       3.000000   507.000000   263.000000    5.00000    0.000000
# 25%     280.250000   890.000000  1139.250000    9.00000    2.000000
# 50%     574.000000  1265.500000  2072.500000   12.00000    5.000000
# 75%     961.000000  1656.750000  3026.250000   16.00000    9.000000
# max    1914.000000  1997.000000  3991.000000   19.00000   18.000000
#
#         talk_time     three_g  touch_screen
# count  500.000000  500.000000    500.000000
# mean    10.930000    0.746000      0.512000
# std      5.555071    0.435734      0.500357
# min      2.000000    0.000000      0.000000
# 25%      6.000000    0.000000      0.000000
# 50%     11.000000    1.000000      1.000000
# 75%     16.000000    1.000000      1.000000
# max     20.000000    1.000000      1.000000

# %%
scaler.transform(X_test)
# Out:
# array([[0.42780749, 1.        , 0.24      , ..., 0.22222222, 1.        ,
#         0.        ],
#        [0.72660428, 1.        , 0.68      , ..., 0.66666667, 1.        ,
#         0.        ],
#        [0.63168449, 0.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.85093583, 1.        , 0.4       , ..., 0.66666667, 1.        ,
#         1.        ],
#        [0.48596257, 0.        , 0.        , ..., 0.83333333, 0.        ,
#         0.        ],
#        [0.86497326, 0.        , 0.44      , ..., 0.05555556, 0.        ,
#         1.        ]])

# %%
X_test_scaled=scaler.transform(X_test)

# %%
print(X_test_scaled)
# Out:
# [[0.42780749 1.         0.24       ... 0.22222222 1.         0.        ]
#  [0.72660428 1.         0.68       ... 0.66666667 1.         0.        ]
#  [0.63168449 0.         0.         ... 1.         0.         0.        ]
#  ...
#  [0.85093583 1.         0.4        ... 0.66666667 1.         1.        ]
#  [0.48596257 0.         0.         ... 0.83333333 0.         0.        ]
#  [0.86497326 0.         0.44       ... 0.05555556 0.         1.        ]]

# %%
from sklearn.linear_model import LogisticRegression
s = LogisticRegression()
model=s.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
yp = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,yp))
# Out:
# 0.626

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78       128
#            1       0.56      0.54      0.55       134
#            2       0.45      0.43      0.44       117
#            3       0.69      0.76      0.72       121
#
#     accuracy                           0.63       500
#    macro avg       0.62      0.62      0.62       500
# weighted avg       0.62      0.63      0.62       500
